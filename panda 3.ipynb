# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna(axis=1,inplace=True)    #inplace --- to make chnages to original dataframe and save it

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.isnull().sum()    # count of null in each columns     axis=0 (default , rows)  axis=1(columns)
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# dtype: int64

# %%
df.dropna(axis=1, thresh=800)   # thresh hold - MIN NON-NA values to be present else delete that column.
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.dropna(axis=1, thresh=800, how=all)     # how = all/any, all -- it checks if all values are NA then drop  | any -- if any one value is NA then delete that entire row or column
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.fillna(value='suraj')   # fill value NA with 'suraj'
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df.fillna(value=df['Age'].mean())   # fill all NA with avg of age
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-561774d48d19> in <module>
# ...

# %%
df["Age"].fillna(value=df['Age'].mean(),inplace=True)                     # fill NA in "age" column wil avg age of all.

# %%
df

# %%
df.groupby('Survived').describe()

# %%
df.groupby('Survived').describe().T    #transpose

# %%
df.groupby('Survived').describe()['Fare']   #select specipic column

# %%
df.groupby('Survived').describe()['Pclass'].transpose()         # T   or   transpose()

# %%
########################################################################################################################

# %%
#dataset link - https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

df=pd.read_csv('bank.csv',sep=";")

# %%
l=[]
for i in df['education'].unique():
    l.append(df[df['education'] == i ])

# %%
df1=l[0].head()

# %%
df2=l[1].head()

# %%
df1

# %%
df2

# %%
#concate data frame at row level, axis=0 by dafault  ...kind of union but not exactly
pd.concat([df2,df1])

# %%
#concate data frame at column level , axis=1

# %%
df2=l[1].head()[['age','marital','balance']]

# %%
df2

# %%
df1=l[0].head()[['age','loan','day']]

# %%
df1

# %%
df3=pd.concat([df2,df1],axis=1)

# %%
df3

# %%
# select age .......but we have two age columns, how to select second one???

df3['age']

# %%
#LOC-- ALWAYS TRIES TO TAKE NAMED INDEX 
#ILOC -- ALWAYS TRIES TO INTERGER, DEFAULT ONE   (integer location)

# %%
df3.iloc[:,3]        # :  means all rows , 3 means column index

# %%
df3.iloc[:,[3,4]]

# %%
df3

# %%
df3.iloc[[4,5],[3,4]]    # integer , inbuilt index loc is used

# %%
df3.loc[[4,36]]      #named index loc is used

# %%
df3.loc[[4,36],['age']]

# %%
df2

# %%
#fetch selected block of data using named loc

# %%
df2.loc[[7,10],['marital','default']]

# %%
#fetch selected block of data using interger-loc  (inbuild index)

# %%
df2.iloc[[2,3],[1,2]]

# %%
df1

# %%
df2

# %%
pd.merge(df1,df2)   # by default how='inner' merge operation and on=None

# %%
pd.merge(df1,df2,on=None)      #same o/p as above

# %%
pd.merge(df1,df2,on='age',how='left')       # df1  is left and df2 is right depending on its location and HOW describes the type of join to perform

# %%
# join operation

# %%
df1 = df1.set_index('age')      # df1.reset_index('age')  to reset index back to normal

# %%
df1

# %%
df2 = df2.set_index('age')

# %%
df2.rename(columns={'marital':'marital1','balance':'balance1'},inplace=True)   # try to rename ..not required

# %%
df2

# %%
df1.join(df2)        # by default join is how=left , merge will join based on 'ON' but with join we join on index

# %%
df1.join(df2,how='inner')    #df1 is calling df and df2 is other df and if column name is same then join will NOT be performed

# %%
# merge VS Join
