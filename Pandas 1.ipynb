# %%
import pandas as pd

# %%
pd.read_csv('C:\\Users\\rashmi\\Downloads\\FSDS_September\\Course_Resources_All_Materials\\5thJune\\Customers.csv')
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df=pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
df
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df)
# Out:
# list

# %%
len(df)
# Out:
# 1

# %%
df[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
url="https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests

# %%
data=requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data1=data.json()

# %%
data1
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55434',
#   'id': 1931253998,
#   'node_id': 'PR_kwDOAA0YD85cKoOW',
#   'number': 55434,
#   'title': 'Backport PR #55380 on branch 2.1.x (CI: Exclude benchmarks directory when publishing docs)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
# ...

# %%
len(data1)
# Out:
# 30

# %%
for i in range(len(data1)):
    print(data1[i]['user']['id'])
# Out:
# 39504233
# 143710553
# 8078968
# 76816026
# 92333742
# 45562402
# 1020496
# 61329810
# 8078968
# 15113894
# 33491632
# 35495924
# 8078968
# 136445532
# 61934744
# 75316256
# 61934744
# 1160474
# 16059111
# 1555705
# 38099496
# 108576690
# 25709809
# 8078968
# 45562402
# 61934744
# 5097759
# 40875798
# 46636284
# 8078968

# %%
pd.DataFrame(data1)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
df=pd.DataFrame(data1,columns=['id','url','repository_url','labels_url'])

# %%
df
# Out:
#             id                                                url  \
# 0   1931253998  https://api.github.com/repos/pandas-dev/pandas...
# 1   1931195355  https://api.github.com/repos/pandas-dev/pandas...
# 2   1931038941  https://api.github.com/repos/pandas-dev/pandas...
# 3   1931010416  https://api.github.com/repos/pandas-dev/pandas...
# 4   1930964649  https://api.github.com/repos/pandas-dev/pandas...
# 5   1930955412  https://api.github.com/repos/pandas-dev/pandas...
# 6   1930697149  https://api.github.com/repos/pandas-dev/pandas...
# 7   1930665829  https://api.github.com/repos/pandas-dev/pandas...
# 8   1930551821  https://api.github.com/repos/pandas-dev/pandas...
# 9   1930184566  https://api.github.com/repos/pandas-dev/pandas...
# 10  1929764125  https://api.github.com/repos/pandas-dev/pandas...
# 11  1929761862  https://api.github.com/repos/pandas-dev/pandas...
# 12  1928775852  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
type(df[['id']])
# Out:
# pandas.core.frame.DataFrame

# %%
import requests
url1 = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
data5 = requests.get(url1)

# %%
data5
# Out:
# <Response [200]>

# %%
data6 = data5.json()

# %%
data6
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/55434',
#   'id': 1931253998,
#   'node_id': 'PR_kwDOAA0YD85cKoOW',
#   'number': 55434,
#   'title': 'Backport PR #55380 on branch 2.1.x (CI: Exclude benchmarks directory when publishing docs)',
#   'user': {'login': 'meeseeksmachine',
#    'id': 39504233,
#    'node_id': 'MDQ6VXNlcjM5NTA0MjMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/meeseeksmachine',
#    'html_url': 'https://github.com/meeseeksmachine',
# ...

# %%
df6=pd.DataFrame(data6)

# %%
df7=pd.DataFrame(df6['user'])

# %%
for i in range(len(data6)): 
    print(data1[i])
# Out:
# {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434', 'repository_url': 'https://api.github.com/repos/pandas-dev/pandas', 'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/labels{/name}', 'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/comments', 'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/55434/events', 'html_url': 'https://github.com/pandas-dev/pandas/pull/55434', 'id': 1931253998, 'node_id': 'PR_kwDOAA0YD85cKoOW', 'number': 55434, 'title': 'Backport PR #55380 on branch 2.1.x (CI: Exclude benchmarks directory when publishing docs)', 'user': {'login': 'meeseeksmachine', 'id': 39504233, 'node_id': 'MDQ6VXNlcjM5NTA0MjMz', 'avatar_url': 'https://avatars.githubusercontent.com/u/39504233?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/meeseeksmachine', 'html_url': 'https://github.com/meeseeksmachine', 'followers_url': 'https://api.github.com/users/meeseeksmachine/followers', 'fol
# ...

# %%
df8=pd.DataFrame(data6['user'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-a14ef86507b8> in <module>
# ----> 1 df8=pd.DataFrame(data6['user'])
#
# TypeError: list indices must be integers or slices, not str
